# %%
""" glob. """
import os
import glob
import copy
import six
import numpy as np
import torch
import torch.utils.data

# %% [markdown]
# ## find_classes関数
# - ルートディレクトリ内のサブディレクトリ（クラス）のリストと、そのインデックスを返す

# %%
def find_classes(root):
    """ find ${root}/${class}/* """
    classes = [d for d in os.listdir(root) if os.path.isdir(os.path.join(root, d))]
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx

# %%
root = "../expriments/dataset/ModelNet40/"
classes, class_to_idx = find_classes(root=root)

# %%
classes, class_to_idx
# Out:
# (['airplane',
#   'bathtub',
#   'bed',
#   'bench',
#   'bookshelf',
#   'bottle',
#   'bowl',
#   'car',
#   'chair',
#   'cone',
#   'cup',
#   'curtain',
#   'desk',
#   'door',
#   'dresser',
#   'flower_pot',
#   'glass_box',
#   'guitar',
#   'keyboard',
#   'lamp',
#   'laptop',
#   'mantel',
#   'monitor',
#   'night_stand',
#   'person',
#   'piano',
#   'plant',
#   'radio',
#   'range_hood',
#   'sink',
#   'sofa',
#   'stairs',
#   'stool',
#   'table',
#   'tent',
#   'toilet',
#   'tv_stand',
#   'vase',
#   'wardrobe',
#   'xbox'],
#  {'airplane': 0,
#   'bathtub': 1,
#   'bed': 2,
#   'bench': 3,
#   'bookshelf': 4,
#   'bottle': 5,
#   'bowl': 6,
#   'car': 7,
#   'chair': 8,
#   'cone': 9,
#   'cup': 10,
#   'curtain': 11,
#   'desk': 12,
#   'door': 13,
#   'dresser': 14,
#   'flower_pot': 15,
#   'glass_box': 16,
#   'guitar': 17,
#   'keyboard': 18,
#   'lamp': 19,
#   'laptop': 20,
#   'mantel': 21,
#   'monitor': 22,
#   'night_stand': 23,
#   'person': 24,
#   'piano': 25,
#   'plant': 26,
#   'radio': 27,
#   'range_hood': 28,
#   'sink': 29,
#   'sofa': 30,
#   'stairs': 31,
#   'stool': 32,
#   'table': 33,
#   'tent': 34,
#   'toilet': 35,
#   'tv_stand': 36,
#   'vase': 37,
#   'wardrobe': 38,
#   'xbox': 39})

# %% [markdown]
# - ラベル
# - ラベルとインデックス
# を確認した.

# %% [markdown]
# ## classes_to_cinfo関数
# - クラスのリストからクラスとそのインデックスを返す

# %%
def classes_to_cinfo(classes):
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx

# %%
classes_to_cinfo(classes)
# Out:
# (['airplane',
#   'bathtub',
#   'bed',
#   'bench',
#   'bookshelf',
#   'bottle',
#   'bowl',
#   'car',
#   'chair',
#   'cone',
#   'cup',
#   'curtain',
#   'desk',
#   'door',
#   'dresser',
#   'flower_pot',
#   'glass_box',
#   'guitar',
#   'keyboard',
#   'lamp',
#   'laptop',
#   'mantel',
#   'monitor',
#   'night_stand',
#   'person',
#   'piano',
#   'plant',
#   'radio',
#   'range_hood',
#   'sink',
#   'sofa',
#   'stairs',
#   'stool',
#   'table',
#   'tent',
#   'toilet',
#   'tv_stand',
#   'vase',
#   'wardrobe',
#   'xbox'],
#  {'airplane': 0,
#   'bathtub': 1,
#   'bed': 2,
#   'bench': 3,
#   'bookshelf': 4,
#   'bottle': 5,
#   'bowl': 6,
#   'car': 7,
#   'chair': 8,
#   'cone': 9,
#   'cup': 10,
#   'curtain': 11,
#   'desk': 12,
#   'door': 13,
#   'dresser': 14,
#   'flower_pot': 15,
#   'glass_box': 16,
#   'guitar': 17,
#   'keyboard': 18,
#   'lamp': 19,
#   'laptop': 20,
#   'mantel': 21,
#   'monitor': 22,
#   'night_stand': 23,
#   'person': 24,
#   'piano': 25,
#   'plant': 26,
#   'radio': 27,
#   'range_hood': 28,
#   'sink': 29,
#   'sofa': 30,
#   'stairs': 31,
#   'stool': 32,
#   'table': 33,
#   'tent': 34,
#   'toilet': 35,
#   'tv_stand': 36,
#   'vase': 37,
#   'wardrobe': 38,
#   'xbox': 39})

# %% [markdown]
# ### find_classes関数との違い
# - find_classes : ディレクトリを直接検索
# - classes_to_cinfo : すでにクラスのリストが存在するとき

# %% [markdown]
# ## glob_dataset関数
# - 与えられたパターンに従って, 指定されたクラス内のファイルをグローバルに取得
# - グローバルパス（'\${root}/\${class}/\${ptns[i]}'）を使用してファイルを取得し, それらのファイルと対応するクラスのインデックスのペアのリストを返す

# %%
def glob_dataset(root, class_to_idx, ptns):
    """ glob ${root}/${class}/${ptns[i]} """
    root = os.path.expanduser(root)
    samples = []
    #class_size = [0 for i in range(len(class_to_idx))]
    for target in sorted(os.listdir(root)):
        d = os.path.join(root, target)
        if not os.path.isdir(d):
            continue

        target_idx = class_to_idx.get(target)
        if target_idx is None:
            continue

        #count = 0
        for i, ptn in enumerate(ptns):
            gptn = os.path.join(d, ptn)
            names = glob.glob(gptn)
            for path in sorted(names):
                item = (path, target_idx)
                samples.append(item)
                #count += 1
        #class_size[target_idx] = count

    return samples

# %%
ptns = ['train/*.off', 'test/*.off']
samples = glob_dataset(root, class_to_idx, ptns)

# %%
len(samples)
# Out:
# 12311

# %%
samples
# Out:
# [('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0001.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0002.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0003.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0004.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0005.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0006.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0007.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0008.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0009.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0010.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0011.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0012.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0013.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0014.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0015.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0016.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0017.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0018.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0019.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0020.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0021.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0022.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0023.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0024.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0025.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0026.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0027.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0028.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0029.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0030.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0031.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0032.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0033.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0034.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0035.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0036.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0037.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0038.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0039.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0040.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0041.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0042.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0043.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0044.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0045.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0046.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0047.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0048.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0049.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0050.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0051.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0052.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0053.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0054.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0055.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0056.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0057.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0058.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0059.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0060.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0061.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0062.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0063.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0064.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0065.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0066.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0067.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0068.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0069.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0070.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0071.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0072.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0073.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0074.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0075.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0076.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0077.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0078.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0079.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0080.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0081.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0082.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0083.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0084.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0085.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0086.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0087.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0088.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0089.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0090.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0091.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0092.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0093.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0094.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0095.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0096.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0097.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0098.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0099.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0100.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0101.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0102.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0103.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0104.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0105.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0106.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0107.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0108.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0109.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0110.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0111.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0112.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0113.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0114.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0115.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0116.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0117.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0118.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0119.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0120.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0121.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0122.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0123.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0124.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0125.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0126.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0127.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0128.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0129.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0130.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0131.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0132.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0133.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0134.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0135.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0136.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0137.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0138.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0139.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0140.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0141.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0142.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0143.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0144.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0145.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0146.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0147.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0148.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0149.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0150.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0151.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0152.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0153.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0154.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0155.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0156.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0157.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0158.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0159.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0160.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0161.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0162.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0163.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0164.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0165.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0166.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0167.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0168.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0169.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0170.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0171.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0172.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0173.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0174.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0175.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0176.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0177.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0178.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0179.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0180.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0181.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0182.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0183.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0184.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0185.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0186.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0187.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0188.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0189.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0190.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0191.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0192.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0193.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0194.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0195.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0196.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0197.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0198.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0199.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0200.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0201.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0202.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0203.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0204.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0205.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0206.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0207.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0208.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0209.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0210.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0211.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0212.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0213.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0214.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0215.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0216.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0217.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0218.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0219.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0220.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0221.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0222.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0223.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0224.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0225.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0226.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0227.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0228.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0229.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0230.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0231.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0232.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0233.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0234.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0235.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0236.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0237.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0238.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0239.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0240.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0241.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0242.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0243.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0244.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0245.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0246.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0247.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0248.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0249.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0250.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0251.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0252.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0253.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0254.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0255.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0256.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0257.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0258.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0259.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0260.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0261.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0262.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0263.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0264.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0265.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0266.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0267.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0268.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0269.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0270.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0271.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0272.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0273.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0274.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0275.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0276.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0277.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0278.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0279.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0280.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0281.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0282.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0283.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0284.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0285.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0286.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0287.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0288.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0289.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0290.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0291.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0292.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0293.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0294.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0295.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0296.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0297.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0298.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0299.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0300.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0301.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0302.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0303.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0304.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0305.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0306.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0307.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0308.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0309.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0310.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0311.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0312.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0313.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0314.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0315.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0316.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0317.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0318.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0319.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0320.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0321.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0322.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0323.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0324.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0325.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0326.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0327.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0328.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0329.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0330.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0331.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0332.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0333.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0334.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0335.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0336.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0337.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0338.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0339.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0340.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0341.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0342.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0343.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0344.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0345.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0346.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0347.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0348.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0349.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0350.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0351.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0352.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0353.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0354.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0355.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0356.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0357.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0358.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0359.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0360.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0361.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0362.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0363.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0364.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0365.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0366.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0367.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0368.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0369.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0370.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0371.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0372.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0373.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0374.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0375.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0376.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0377.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0378.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0379.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0380.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0381.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0382.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0383.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0384.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0385.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0386.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0387.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0388.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0389.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0390.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0391.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0392.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0393.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0394.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0395.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0396.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0397.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0398.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0399.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0400.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0401.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0402.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0403.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0404.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0405.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0406.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0407.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0408.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0409.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0410.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0411.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0412.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0413.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0414.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0415.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0416.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0417.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0418.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0419.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0420.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0421.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0422.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0423.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0424.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0425.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0426.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0427.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0428.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0429.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0430.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0431.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0432.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0433.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0434.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0435.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0436.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0437.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0438.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0439.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0440.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0441.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0442.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0443.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0444.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0445.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0446.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0447.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0448.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0449.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0450.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0451.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0452.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0453.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0454.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0455.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0456.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0457.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0458.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0459.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0460.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0461.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0462.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0463.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0464.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0465.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0466.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0467.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0468.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0469.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0470.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0471.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0472.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0473.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0474.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0475.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0476.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0477.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0478.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0479.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0480.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0481.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0482.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0483.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0484.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0485.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0486.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0487.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0488.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0489.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0490.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0491.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0492.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0493.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0494.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0495.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0496.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0497.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0498.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0499.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0500.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0501.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0502.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0503.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0504.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0505.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0506.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0507.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0508.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0509.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0510.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0511.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0512.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0513.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0514.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0515.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0516.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0517.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0518.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0519.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0520.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0521.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0522.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0523.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0524.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0525.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0526.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0527.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0528.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0529.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0530.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0531.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0532.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0533.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0534.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0535.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0536.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0537.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0538.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0539.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0540.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0541.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0542.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0543.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0544.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0545.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0546.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0547.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0548.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0549.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0550.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0551.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0552.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0553.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0554.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0555.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0556.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0557.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0558.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0559.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0560.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0561.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0562.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0563.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0564.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0565.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0566.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0567.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0568.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0569.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0570.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0571.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0572.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0573.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0574.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0575.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0576.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0577.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0578.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0579.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0580.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0581.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0582.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0583.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0584.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0585.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0586.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0587.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0588.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0589.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0590.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0591.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0592.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0593.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0594.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0595.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0596.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0597.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0598.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0599.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0600.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0601.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0602.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0603.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0604.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0605.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0606.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0607.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0608.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0609.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0610.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0611.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0612.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0613.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0614.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0615.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0616.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0617.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0618.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0619.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0620.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0621.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0622.off', 0),
#  ('../expriments/dataset/ModelNet40/airplane\\train\\airplane_0623.off', 0),
# ...
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0049.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0050.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0051.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0052.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0053.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0054.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0055.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0056.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0057.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0058.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0059.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0060.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0061.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0062.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0063.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0064.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0065.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0066.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0067.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0068.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0069.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0070.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0071.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0072.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0073.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0074.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0075.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0076.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0077.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0078.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0079.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0080.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0081.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0082.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0083.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0084.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0085.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0086.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0087.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0088.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0089.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0090.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0091.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0092.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0093.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0094.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0095.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0096.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0097.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0098.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0099.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0100.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0101.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0102.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0103.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0104.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0105.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\train\\bathtub_0106.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0107.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0108.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0109.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0110.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0111.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0112.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0113.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0114.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0115.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0116.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0117.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0118.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0119.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0120.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0121.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0122.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0123.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0124.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0125.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0126.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0127.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0128.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0129.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0130.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0131.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0132.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0133.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0134.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0135.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0136.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0137.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0138.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0139.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0140.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0141.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0142.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0143.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0144.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0145.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0146.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0147.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0148.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0149.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0150.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0151.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0152.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0153.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0154.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0155.off', 1),
#  ('../expriments/dataset/ModelNet40/bathtub\\test\\bathtub_0156.off', 1),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0001.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0002.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0003.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0004.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0005.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0006.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0007.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0008.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0009.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0010.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0011.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0012.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0013.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0014.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0015.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0016.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0017.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0018.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0019.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0020.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0021.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0022.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0023.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0024.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0025.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0026.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0027.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0028.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0029.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0030.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0031.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0032.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0033.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0034.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0035.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0036.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0037.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0038.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0039.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0040.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0041.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0042.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0043.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0044.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0045.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0046.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0047.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0048.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0049.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0050.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0051.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0052.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0053.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0054.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0055.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0056.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0057.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0058.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0059.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0060.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0061.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0062.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0063.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0064.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0065.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0066.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0067.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0068.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0069.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0070.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0071.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0072.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0073.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0074.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0075.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0076.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0077.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0078.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0079.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0080.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0081.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0082.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0083.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0084.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0085.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0086.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0087.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0088.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0089.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0090.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0091.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0092.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0093.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0094.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0095.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0096.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0097.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0098.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0099.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0100.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0101.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0102.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0103.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0104.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0105.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0106.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0107.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0108.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0109.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0110.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0111.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0112.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0113.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0114.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0115.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0116.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0117.off', 2),
#  ('../expriments/dataset/ModelNet40/bed\\train\\bed_0118.off', 2),
#  ...]

# %% [markdown]
# ディレクトリを走査し, ファイルを取得することができた.
#
# ファイル名とクラスのインデックスが確認できる.

# %% [markdown]
# # Globsetクラス
# - `torch.utils.data.Dataset`クラスを拡張したデータセットクラス
# - コンストラクタでルートディレクトリ, ファイルのパターン, ファイルの読み込み関数, オプションのデータ変換, クラス情報を受け取る
# - クラスは, 指定されたパターンに基づいて取得されたサンプルのリストと, そのクラスのインデックスのペアを保持
# - データセット内のサンプル数, サンプルの取得メソッド, およびほかの補助メソッドを実装
# - `split`メソッドはデータセットを指定された割合で2つに分割する
#
# `datasets.py`にて継承されて使われている.
#
# ## \_\_init__(self, rootdir, pattern, fileloader, transform=None, classinfo=None)
# - `rootdir` : `dataset_path`という形で与えられる
# - `pattern` : 上記の例のように[train/*.off]などで与えられる
# - `fileloader` : ファイルの読み込み関数を示す
# - `transform` : データの前処理
# - `classinfo` : クラス情報

# %%
class Globset(torch.utils.data.Dataset):
    """ glob ${rootdir}/${classes}/${pattern}
    """
    def __init__(self, rootdir, pattern, fileloader, transform=None, classinfo=None):
        super().__init__()

        # patternが文字列ならリストに変換する
        if isinstance(pattern, six.string_types):
            pattern = [pattern]

        # cinfoが与えられたらそれを利用（train時にargsで与えているやつ）
        # 与えられてないなら走査する -> 実行速度に影響？
        if classinfo is not None:
            classes, class_to_idx = classinfo
        else:
            classes, class_to_idx = find_classes(rootdir)

        # 全データ取得（ファイル名とクラスのインデックスのみ）
        samples = glob_dataset(rootdir, class_to_idx, pattern)
        if not samples:
            raise RuntimeError("Empty: rootdir={}, pattern(s)={}".format(rootdir, pattern))

        # 使用する変数をメンバに代入
        self.rootdir = rootdir
        self.pattern = pattern
        self.fileloader = fileloader
        self.transform = transform

        self.classes = classes
        self.class_to_idx = class_to_idx
        self.samples = samples

    def __repr__(self):
        '''デバッグ用に便利'''
        fmt_str = 'Dataset {}\n'.format(self.__class__.__name__)
        fmt_str += '    Number of datapoints: {}\n'.format(self.__len__())
        fmt_str += '    Root Location: {}\n'.format(self.rootdir)
        fmt_str += '    File Patterns: {}\n'.format(self.pattern)
        fmt_str += '    File Loader: {}\n'.format(self.fileloader)
        tmp = '    Transforms (if any): '
        fmt_str += '{0}{1}\n'.format(tmp,
                                     self.transform.__repr__().replace('\n', '\n' + ' ' * len(tmp)))
        return fmt_str

    def __len__(self):
        '''データ数取得'''
        return len(self.samples)

    def __getitem__(self, index):
        '''データを読み込む'''
        path, target = self.samples[index]  # targetはラベル
        sample = self.fileloader(path)
        # 前処理があるなら適用
        if self.transform is not None:
            sample = self.transform(sample)

        return sample, target  # 読み込んだデータとラベルを返す

    def num_classes(self):
        '''クラス数取得'''
        return len(self.classes)

    def class_name(self, cidx):
        '''クラス名取得'''
        return self.classes[cidx]

    def indices_in_class(self, cidx):
        targets = np.array(list(map(lambda s: s[1], self.samples)))  # すべてのラベルをリストにする
        return np.where(targets == cidx).tolist()  # cidxに対応するラベルに等しいクラスのみを返す

    def select_classes(self, cidxs):
        '''指定されたクラスに属するサンプルのインデックスを返す'''
        indices = []
        for i in cidxs:
            idxs = self.indices_in_class(i)
            indices.extend(idxs)
        return indices

    def split(self, rate):
        """ dateset -> dataset1, dataset2. s.t.
            len(dataset1) = rate * len(dataset),
            len(dataset2) = (1-rate) * len(dataset)
        """
        orig_size = len(self)
        select = np.zeros(orig_size, dtype=int)
        csize = np.zeros(len(self.classes), dtype=int)
        dsize = np.zeros(len(self.classes), dtype=int)

        for i in range(orig_size):
            _, target = self.samples[i]
            csize[target] += 1
        dsize = (csize * rate).astype(int)
        for i in range(orig_size):
            _, target = self.samples[i]
            if dsize[target] > 0:
                select[i] = 1
                dsize[target] -= 1

        dataset1 = copy.deepcopy(self)
        dataset2 = copy.deepcopy(self)

        samples1 = list(map(lambda i: dataset1.samples[i], np.where(select == 1)[0]))
        samples2 = list(map(lambda i: dataset2.samples[i], np.where(select == 0)[0]))

        dataset1.samples = samples1
        dataset2.samples = samples2
        return dataset1, dataset2
